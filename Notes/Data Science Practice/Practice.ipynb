# %% [markdown]
# <h1 id='title'> Data Science Practice </h1>

# %%
import pandas as pd

# %%
excel_file='DataFromIBM.xlsx'
df=pd.read_excel(excel_file)
df
# Out:
#             Artist                            Album  Released (Year)  \
# 0  Michael Jackson                         Thriller             1982
# 1            AC/DC                    Back in Black             1980
# 2       Pink Floyd        The Dark Side of the Moon             1973
# 3  Whitney Houston                    The Bodyguard             1992
# 4        Meat Loaf                  Bat Out of Hell             1977
# 5           Eagles  Their Greatest Hits (1971-1975)             1976
# 6         Bee Gees             Saturday Night Fever             1977
# 7    Fleetwood Mac                          Rumours             1977
#
#                Length                        Genre  \
# 0 1900-01-01 00:41:54               Pop, rock, R&B
# 1 1900-01-01 00:41:46                    Hard rock
# 2 1900-01-01 00:42:24             Progressive rock
# 3 1900-01-01 00:57:19    Soundtrack/R&B, soul, pop
# 4 1900-01-01 00:46:08  Hard rock, progressive rock
# 5 1900-01-01 00:42:43   Rock, soft rock, folk rock
# 6 1900-01-01 01:15:29                        Disco
# 7 1900-01-01 00:39:36                    Soft rock
#
#    Music recording sales (millions)  Claimed sales (millions) Release Date  \
# 0                              46.0                        65   1982-11-30
# 1                              26.1                        50   1980-07-25
# 2                              24.2                        45   1973-03-01
# 3                              26.1                        50   1980-07-25
# 4                              20.6                        43   1977-10-21
# 5                              32.2                        42   1976-02-17
# 6                              20.6                        40   1977-11-15
# 7                              27.9                        40   1977-02-04
#
#   Soundtrack  Rating (friends)
# 0        NaN              10.0
# 1        NaN               8.5
# 2        NaN               9.5
# 3          Y               7.0
# 4        NaN               7.0
# 5        NaN               9.5
# 6          Y               9.0
# 7        NaN               9.5

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Artist, Album, Released (Year), Length, Genre, Music recording sales (millions), Claimed sales (millions), Release Date, Soundtrack, Rating (friends)]
# Index: []

# %%
x=df[['Length']]
x
# Out:
#                Length
# 0 1900-01-01 00:41:54
# 1 1900-01-01 00:41:46
# 2 1900-01-01 00:42:24
# 3 1900-01-01 00:57:19
# 4 1900-01-01 00:46:08
# 5 1900-01-01 00:42:43
# 6 1900-01-01 01:15:29
# 7 1900-01-01 00:39:36

# %%
x=df[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0,0]
# Out:
# 'Michael Jackson'

# %% [markdown]
# <h2 id="quiz"> Quiz on dataframe </h2>

# %%
q=df[['Rating (friends)']]
q
# Out:
#    Rating (friends)
# 0              10.0
# 1               8.5
# 2               9.5
# 3               7.0
# 4               7.0
# 5               9.5
# 6               9.0
# 7               9.5

# %%
q=df[['Released (Year)','Artist']]
q
# Out:
#    Released (Year)           Artist
# 0             1982  Michael Jackson
# 1             1980            AC/DC
# 2             1973       Pink Floyd
# 3             1992  Whitney Houston
# 4             1977        Meat Loaf
# 5             1976           Eagles
# 6             1977         Bee Gees
# 7             1977    Fleetwood Mac

# %%
df.iloc[1,2]
# Out:
# 1980

# %%
new_index=['a','b','c','d','e','f','g','h']

df_new=df
df_new.index=new_index
df_new
# df_new.loc['a','Artist']
# df_new.loc['a':'d','Artist']
# Out:
#             Artist                            Album  Released (Year)  \
# a  Michael Jackson                         Thriller             1982
# b            AC/DC                    Back in Black             1980
# c       Pink Floyd        The Dark Side of the Moon             1973
# d  Whitney Houston                    The Bodyguard             1992
# e        Meat Loaf                  Bat Out of Hell             1977
# f           Eagles  Their Greatest Hits (1971-1975)             1976
# g         Bee Gees             Saturday Night Fever             1977
# h    Fleetwood Mac                          Rumours             1977
#
#                Length                        Genre  \
# a 1900-01-01 00:41:54               Pop, rock, R&B
# b 1900-01-01 00:41:46                    Hard rock
# c 1900-01-01 00:42:24             Progressive rock
# d 1900-01-01 00:57:19    Soundtrack/R&B, soul, pop
# e 1900-01-01 00:46:08  Hard rock, progressive rock
# f 1900-01-01 00:42:43   Rock, soft rock, folk rock
# g 1900-01-01 01:15:29                        Disco
# h 1900-01-01 00:39:36                    Soft rock
#
#    Music recording sales (millions)  Claimed sales (millions) Release Date  \
# a                              46.0                        65   1982-11-30
# b                              26.1                        50   1980-07-25
# c                              24.2                        45   1973-03-01
# d                              26.1                        50   1980-07-25
# e                              20.6                        43   1977-10-21
# f                              32.2                        42   1976-02-17
# g                              20.6                        40   1977-11-15
# h                              27.9                        40   1977-02-04
#
#   Soundtrack  Rating (friends)
# a        NaN              10.0
# b        NaN               8.5
# c        NaN               9.5
# d          Y               7.0
# e        NaN               7.0
# f        NaN               9.5
# g          Y               9.0
# h        NaN               9.5
